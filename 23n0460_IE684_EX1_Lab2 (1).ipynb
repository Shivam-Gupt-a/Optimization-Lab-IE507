# %% [markdown]
# #Exercise 1
# ##part 1
# We have the function
# $g(x) = (x_1 + 49)^2 + (x_2 - 36)^2$
#
# we can convert it in the form $(x^T A x + b^T x + c)$ as follows:
#
# Then we Factorize the quadratic terms:
# $ g(x) = (x_1 + 49)^2 + (x_2 - 36)^2 $
#
# $ = (x_1^2 + 98x_1 + 49^2) + (x_2^2 - 72x_2 + 36^2) $
#
# combine the $x_1$ and $x_2$ terms:
# $= x_1^2 + x_2^2 + 98x_1 - 72x_2 + 49^2 + 36^2 $
#
#  matrix form is given by:
# $ g(x) = \begin{bmatrix} x_1 & x_2 \end{bmatrix} \begin{bmatrix} 1 & 0 \\ 0 & 1 \end{bmatrix} \begin{bmatrix} x_1 \\ x_2 \end{bmatrix} + \begin{bmatrix} 98 & -72 \end{bmatrix} \begin{bmatrix} x_1 \\ x_2 \end{bmatrix} + 49^2 + 36^2 $
#
# Now, we have the form \(x^T A x + b^T x + c\):
# $ A = \begin{bmatrix} 1 & 0 \\ 0 & 1 \end{bmatrix} $
#
#  $b = \begin{bmatrix} 98 \\ -72 \end{bmatrix} $
#
#  $c = 49^2 + 36^2 $
#
# So, \( g(x) \) can be expressed in the desired form as:
# $g(x) = x^T A x + b^T x + c $
#
# where
# $A = \begin{bmatrix} 1 & 0 \\ 0 & 1 \end{bmatrix}$
# $b = \begin{bmatrix} 98 \\ -72 \end{bmatrix} $
# $ c = 49^2 + 36^2 $

# %% [markdown]
# ## finding the minimiser and minimum value for the function
# $ f(x) = 256(x_2 - x_1^2)^2 + (2 - x_1)^2 $:
#
# 1. First we find the partial derivatives:
# $
# \frac{\partial f}{\partial x_1} = -1024x_1(x_2 - x_1^2) - 2(2 - x_1)
# $
# $
# \frac{\partial f}{\partial x_2} = 512(x_2 - x_1^2)
# $
#
# 2. then set the partial derivatives equal to zero and solve for $ x_1 $ and $ x_2 $:
# $
# -1024x_1(x_2 - x_1^2) - 2(2 - x_1) = 0
# $
# $
# 512(x_2 - x_1^2) = 0
# $
#
# Solving the below equations:
#
# $
# 1026x_1^3 - 1024x_1x_2 + 2x_1 - 4 = 0
# $
# $
# x_2 = x_1^2
# $
#
# Substituting $ x_2 = x_1^2 $ into the first equation:
#
# $
# 1026x_1^3 - 1024x_1(x_1^2) + 2x_1 - 4 = 0
# $
# $
# 2x_1 - 4 = 0
# $
# $
# x_1 = 2
# $
#
# Now, substitute $ x_1 = 2 $ into $ x_2 = x_1^2 $:
# $
# x_2 = 2^2 = 4
# $
#
# So, the minimizer for $ f(x) $ is $ (x_1, x_2) = (2, 4) $.
#
# Now, find the minimum function value by substituting these values into $ f(x) $:
# $
# f(2, 4) = 0
# $
#
# Therefore, the minimum function value for $ f(x) $ is 0, and the minimizer is $ (x_1, x_2) = (2, 4) $.
#
# ---
#
# For $ g(x) = (x_1 + 49)^2 + (x_2 - 36)^2 $:
#
# 1. Find the partial derivatives:
# $
# \frac{\partial g}{\partial x_1} = 2(x_1 + 49)
# $
# $
# \frac{\partial g}{\partial x_2} = 2(x_2 - 36)
# $
#
# 2. Set the partial derivatives equal to zero and solve for $ x_1 $ and $ x_2 $:
# $
# 2(x_1 + 49) = 0
# $
# $
# 2(x_2 - 36) = 0
# $
#
# Solving these equations:
#
# $
# x_1 = -49
# $
# $
# x_2 = 36
# $
#
# So, the minimizer for $ g(x) $ is $ (x_1, x_2) = (-49, 36) $.
#
# Now, We will find the minimum function value by substituting these values into $ g(x) $:
# $
# g(-49, 36) = 0
# $
#
# Therefore, the minimum function value for $ g(x) $ is 0, and the minimizer is $ (x_1, x_2) = (-49, 36) $.

# %% [markdown]
# #Part 2
# We have the function
# $ g(x) = (x_1 + 49)^2 + (x_2 - 36)^2 $, with gradient
# $ \frac{\partial g}{\partial x_1} = 2(x_1 + 49) $
# $ \frac{\partial g}{\partial x_2} = 2(x_2 - 36) $
#
# First we find the analytical solution to minimize
# $ g(x - \alpha \nabla g(x)) $ in closed form.
#
# Let $ x' = x - \alpha \nabla g(x) $, and we want to minimize $ g(x') $. The expression for $ g(x') $ is:
# $ g(x') = \left(x_1 - \alpha \frac{\partial g}{\partial x_1}\right)^2 + \left(x_2 - \alpha \frac{\partial g}{\partial x_2}\right)^2 $
#
# Substitute the values for $ \frac{\partial g}{\partial x_1} $ and $ \frac{\partial g}{\partial x_2} $:
# $ g(x') = \left(x_1 - \alpha \cdot 2(x_1 + 49)\right)^2 + \left(x_2 - \alpha \cdot 2(x_2 - 36)\right)^2 $
#
# then simplify the expression for $ g(x') $:
# $ g(x') = (1 - 2\alpha)(x_1 + 49)^2 + (1 - 2\alpha)(x_2 - 36)^2 $
#
# Now, differentiate $ g(x') $ with respect to $ \alpha $ and set it equal to zero to find the optimal $ \alpha $:
# $ \frac{d}{d\alpha} g(x') = -2(x_1 + 49)^2 - 2(x_2 - 36)^2 + 4\alpha(x_1 + 49)^2 + 4\alpha(x_2 - 36)^2 = 0 $
#
# after solving this equation we will get the analytical solution for $ \alpha $ = 0.5

# %% [markdown]
# The analytical solution to $ \min_{\alpha \geq 0} f(x - \alpha \nabla f(x)) $ can sometimes be found in closed form, depending on the specific form of the function $ f(x) $. However, it is not always guaranteed that a closed-form solution exists. Whether a closed-form solution can be found depends on the complexity and nonlinearity of the function.
#
# To explore further, let's consider the function $ f(x) = 256(x_2 - x_1^2)^2 + (2 - x_1)^2 $, for which we previously found the minimizer and minimum function value.
#
# The update rule $ x' = x - \alpha \nabla f(x) $ is as follows:
# $ x'_1 = x_1 + 1024\alpha x_1(x_1^2 - x_2) + 2\alpha(2 - x_1) $
# $ x'_2 = x_2 - 512\alpha(x_1^2 - x_2) $
#
# Now, to find the analytical solution, we need to minimize $ f(x') $ with respect to $ \alpha $. The expression for $ f(x') $ is:
# $ f(x') = 256(x'_2 - (x'_1)^2)^2 + (2 - x'_1)^2 $
#
# Substituting the expressions for $ x'_1 $ and $ x'_2 $, we get:
# $ f(x') = 256(x_2 - 512\alpha(x_1^2 - x_2) - (x_1 + 1024\alpha x_1(x_1^2 - x_2) + 2\alpha(2 - x_1))^2)^2 + (2 - (x_1 + 1024\alpha x_1(x_1^2 - x_2) + 2\alpha(2 - x_1)))^2 $
#
# The expression becomes highly nonlinear due to the quadratic terms and the dependency on $ \alpha $. Solving for the minimum $ \alpha $ in closed form may not be straightforward, and it might require numerical methods.
#
# In general, the existence of a closed-form solution depends on the specific form of the function $ f(x) $, and for more complex functions, numerical optimization methods may be required to find the optimal $ \alpha $.
#
# Thus for this solution the value of  $ \alpha $ does not exist in closed form

# %% [markdown]
# #Part3

# %%
import numpy as np

def g(x):
    return (x[0] + 49)**2 + (x[1] - 36)**2

def gradient_g(x):
    return np.array([2 * (x[0] + 49), 2 * (x[1] - 36)])

def line_search1(x, p, alpha=0.5, beta=0.8):
     #Backtracking line search to find the optimal step size
      t = 1.0  # Initial step size

      while g(x + t * p) > g(x) + alpha * t * np.dot(gradient_g(x), p):
          t *= beta

      return t
def line_search(x, p, alpha_range=10):
    # Perform line search to find the optimal step size
    alpha_values = np.linspace(0, 1, alpha_range)
    min_alpha = min(alpha_values, key=lambda alpha: g(x - alpha * p))
    return min_alpha


def gradient_descent(x0, tolerance):
    x = x0
    k = 0
    p = -gradient_g(x)

    while np.linalg.norm(p) > tolerance:
        alpha = line_search1(x, p)
        x = x + alpha * p
        p = -gradient_g(x)
        k += 1

    return x, k

# %%
# storing the values for x when step length is not fixed
def gradient_descent1(x0, tolerance):
    x = x0
    k = 0
    p = -gradient_g(x)
    trajectory1=[x.copy()]

    while np.linalg.norm(p) > tolerance:
        alpha = line_search1(x, p)
        x = x + alpha * p
        trajectory1.append(x.copy())
        p = -gradient_g(x)
        k += 1

    return np.array(trajectory1)

# %%
# storing the values of x when step length is fixed
def gradient_descent2t(x0, tolerance):

    x = x0
    a = 0
    p = -gradient_g(x)
    trajectory = [x.copy()]

    while np.linalg.norm(p) > tolerance:
        alpha = 0.001
        x = x + alpha * p
        trajectory.append(x.copy())
        p = -gradient_g(x)
        a += 1

    return np.array(trajectory)

# %%
def gradient_descent2(x0, tolerance):

    x = x0
    a = 0
    p = -gradient_g(x)
    trajectory = [x.copy()]

    while np.linalg.norm(p) > tolerance:
        alpha = 0.001
        x = x + alpha * p
        trajectory.append(x.copy())
        p = -gradient_g(x)
        a += 1

    return x,a

# %%
x0 = np.array([36, -49])

c=gradient_descent2t(x0, 1e-6)
len(c)
# Out:
# 9641

# %%
# Initial point
x0 = np.array([36, -49])

# Explore a range of tolerances
tolerances = [10**(-p) for p in range(1, 16)]

# Record the number of iterations for each tolerance
iterations = []
iterations2=[]

for tau in tolerances:
    result, num_iterations = gradient_descent(x0, tau)
    iterations.append(num_iterations)
    print(f'Tolerance: {tau}, Iterations: {num_iterations}, Minimum: {result}')

# Display the results
print("Tolerance values:", tolerances)
print("Number of iterations:", iterations)
# Out:
# Tolerance: 0.1, Iterations: 5, Minimum: [-48.98357857  35.98357857]
# Tolerance: 0.01, Iterations: 6, Minimum: [-48.997031  35.997031]
# Tolerance: 0.001, Iterations: 8, Minimum: [-48.99990295  35.99990295]
# Tolerance: 0.0001, Iterations: 9, Minimum: [-48.99998245  35.99998245]
# Tolerance: 1e-05, Iterations: 10, Minimum: [-48.99999683  35.99999683]
# Tolerance: 1e-06, Iterations: 12, Minimum: [-48.9999999  35.9999999]
# Tolerance: 1e-07, Iterations: 13, Minimum: [-48.99999998  35.99999998]
# Tolerance: 1e-08, Iterations: 14, Minimum: [-49.  36.]
# Tolerance: 1e-09, Iterations: 16, Minimum: [-49.  36.]
# Tolerance: 1e-10, Iterations: 17, Minimum: [-49.  36.]
# Tolerance: 1e-11, Iterations: 19, Minimum: [-49.  36.]
# Tolerance: 1e-12, Iterations: 20, Minimum: [-49.  36.]
# Tolerance: 1e-13, Iterations: 21, Minimum: [-49.  36.]
# Tolerance: 1e-14, Iterations: 23, Minimum: [-49.  36.]
# Tolerance: 1e-15, Iterations: 23, Minimum: [-49.  36.]
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(iterations,tolerances)
plt.title('Iterations vs Tolerance')
plt.ylabel('Tolerance')
plt.xlabel('Number of Iterations')
# Out:
# Text(0.5, 0, 'Number of Iterations')

# %%
tolerances_2=[10**(-p) for p in range(1,11)]

# %%
# for the fixed step length
for tau in tolerances_2:
    result, num_iterations = gradient_descent2(x0, tau)
    iterations2.append(num_iterations)
    print(f'Tolerance: {tau}, Iterations_2: {num_iterations}, Minimum: {result}')
# Out:
# Tolerance: 0.1, Iterations_2: 3889, Minimum: [-48.96467404  35.96467404]
# Tolerance: 0.01, Iterations_2: 5039, Minimum: [-48.99646641  35.99646641]
# Tolerance: 0.001, Iterations_2: 6189, Minimum: [-48.99964654  35.99964654]
# Tolerance: 0.0001, Iterations_2: 7340, Minimum: [-48.99996471  35.99996471]
# Tolerance: 1e-05, Iterations_2: 8490, Minimum: [-48.99999647  35.99999647]
# Tolerance: 1e-06, Iterations_2: 9640, Minimum: [-48.99999965  35.99999965]
# Tolerance: 1e-07, Iterations_2: 10790, Minimum: [-48.99999996  35.99999996]
# Tolerance: 1e-08, Iterations_2: 11940, Minimum: [-49.  36.]
# Tolerance: 1e-09, Iterations_2: 13090, Minimum: [-49.  36.]
# Tolerance: 1e-10, Iterations_2: 14241, Minimum: [-49.  36.]

# %%
import matplotlib.pyplot as plt
plt.plot(iterations2,tolerances_2)
plt.title('Iterations vs Tolerance')
plt.ylabel('Tolerance')
plt.xlabel('Number of Iterations')
# Out:
# Text(0.5, 0, 'Number of Iterations')

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function g(x)
def g(x):
    return (x[0] + 49)**2 + (x[1] - 36)**2

# Generate a grid of points for contour plotting
x1_vals = np.linspace(-100, 100, 400)
x2_vals = np.linspace(-100, 100, 400)
X1, X2 = np.meshgrid(x1_vals, x2_vals)
Z = g(np.vstack([X1.ravel(), X2.ravel()]))

# Reshape the flattened array back to the shape of X1 and X2
Z = Z.reshape(X1.shape)

# Plot the level sets of g(x)
plt.figure(figsize=(10, 12))
contour_plot = plt.contour(X1, X2, Z, levels=25, cmap='viridis')
plt.title('Level Sets of g(x)')
plt.xlabel('x1')
plt.ylabel('x2')
plt.colorbar(contour_plot, label='g(x)')
plt.scatter([36], [-49], color='yellow', label='Starting Point')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Below is the optimization trajectory when we take fixed learning rate value to be 0.001

# %%
x0 = np.array([36, -49])
x_range = np.linspace(-40, 40, 300)
y_range = np.linspace(-40, 40, 300)
X, Y = np.meshgrid(x_range, y_range)
Z = g([X, Y])


trajectory = gradient_descent2t(x0, 1e-7)

# Plot level sets and trajectory
plt.contour(X, Y, Z, levels=np.logspace(-1, 4, 10), cmap='viridis')
plt.plot(trajectory[:, 0], trajectory[:, 1], marker='o', color='green', label='Optimization Trajectory')
plt.scatter(trajectory[0, 0], trajectory[0, 1], color='blue', marker='o', label='Starting Point')
plt.title('Level Sets and Optimization Trajectory')
plt.xlabel('x1')
plt.ylabel('x2')
plt.legend()
plt.show()

# %%
# Plot level sets and trajectory
trajectory1=gradient_descent1(x0, 1e-7)
plt.contour(X, Y, Z, levels=np.logspace(-1, 4, 10), cmap='viridis')
plt.plot(trajectory1[:, 0], trajectory1[:, 1], marker='o', color='blue', label='Optimization Trajectory')
plt.scatter(trajectory1[0, 0], trajectory1[0, 1], color='yellow', marker='o', label='Starting Point')
plt.title('Level Sets and  Trajectory')
plt.xlabel('x1')
plt.ylabel('x2')
plt.legend()
plt.show()

# %% [markdown]
# #Part4
# Here are several sortcomings and possible soltuion to deal with for this algorithm
#
#
# Slow Convergence:
#
# Shortcoming: Gradient descent may converge slowly, particularly in regions with shallow gradients. The line search might take small steps, leading to a sluggish algorithm that takes time to reach the minimum.
#
# Possible Solution: Implement acceleration techniques such as momentum, Nesterov accelerated gradient, or utilize more advanced optimization algorithms like BFGS or Adam for faster convergence.
#
# Sensitivity to Initial Conditions:
#
# Shortcoming: The performance of gradient descent can be affected by the initial guess for the parameters.
#
# Possible Solution: Experiment with different initial conditions and consider employing techniques like random initialization or heuristics to enhance robustness.
#
# Local Minima:
#
# Shortcoming: Gradient descent is prone to getting trapped in local minima, hindering its ability to find the global minimum.
#
# Possible Solution: Employ techniques like simulated annealing, genetic algorithms, or multi-start optimization to explore a broader solution space and mitigate the impact of local minima.
